# %%
import pandas as pd

# 1. Read data from a CSV file
df = pd.read_csv('data.csv')

# 2. View the first few rows of the DataFrame
first_rows = df.head()

# 3. View the last few rows of the DataFrame
last_rows = df.tail()

# 4. Get basic statistics of the DataFrame
summary_stats = df.describe()

# 5. Select specific columns from the DataFrame
selected_columns = df[['column1', 'column2']]

# 6. Filter rows based on a condition
filtered_rows = df[df['column1'] > 10]

# 7. Sort the DataFrame by a column
sorted_df = df.sort_values(by='column1', ascending=False)

# 8. Group data and perform aggregation
grouped = df.groupby('category').agg({'column1': 'mean', 'column2': 'sum'})

# 9. Rename columns
df.rename(columns={'old_name': 'new_name'}, inplace=True)

# 10. Drop columns
df.drop(['column1', 'column2'], axis=1, inplace=True)

# 11. Handling missing values
df.dropna()  # Remove rows with missing values
df.fillna(value)  # Fill missing values with a specific value

# 12. Pivot tables
pivot_table = pd.pivot_table(df, values='value', index='index_column', columns='column_to_pivot')

# 13. Merging DataFrames
merged_df = pd.merge(df1, df2, on='common_column', how='inner')

# 14. Concatenating DataFrames
concatenated_df = pd.concat([df1, df2], axis=0)

# 15. Apply a function to DataFrame
df['new_column'] = df['existing_column'].apply(function)

# 16. Save DataFrame to a CSV file
df.to_csv('output.csv', index=False)

# 17. Create a new DataFrame
new_df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# 18. Change the index of a DataFrame
df.set_index('new_index_column', inplace=True)

# 19. Get unique values in a column
unique_values = df['column'].unique()

# 20. Crosstabulation
crosstab = pd.crosstab(df['column1'], df['column2'])

# Additional: Time Series Operations
# You can also perform various time series operations like resampling, date-time indexing, and more using Pandas.

print("First Rows:", first_rows)
print("Last Rows:", last_rows)
print("Summary Statistics:", summary_stats)
print("Selected Columns:", selected_columns)
print("Filtered Rows:", filtered_rows)
print("Sorted DataFrame:", sorted_df)
print("Grouped Data:", grouped)
print("Renamed DataFrame:", df)
print("Merged DataFrame:", merged_df)
print("Concatenated DataFrame:", concatenated_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # 1. Read data from a CSV file
# ----> 4 df = pd.read_csv('data.csv')
#       6 # 2. View the first few rows of the DataFrame
#       7 first_rows = df.head()
#
# ...
