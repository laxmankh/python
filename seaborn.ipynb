# %%
#pratical no_1
import numpy as np
from matplotlib import pyplot as plt
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sb.set_style('whitegrid')
# sb.despine()
sinplot()
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
  
# loading dataset 
data = sns.load_dataset("iris") 
  
# draw lineplot 
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 

# setting the x limit of the plot
plt.xlim(5)
  
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("dark")
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Setting the scale of the plot
sns.set_context("paper")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
lakhan=sns.color_palette()
sns.palplot(lakhan)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# current colot palette
palette = sns.color_palette('Greens', 11)

# sequential color palette
sns.palplot(palette)

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

def plot():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the default color palette
sns.set_palette('vlag')
plt.subplot(211)

# plotting with the color palette
# as vlag
plot()

# setting another default color palette
sns.set_palette('Accent')
plt.subplot(212)
plot()

plt.show()

# %%
#pratical no_2 use whitegrid style
import numpy as np
import matplotlib.pyplot as plt
def sinplot(flip=1):
    x=np.linspace(0,14,100)
    for i in range(1,5):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)
import seaborn as sb
sb.set_style('whitegrid')
sb.set()
sinplot()
plt.show()

# %%
#pratical no_2 use despine function --->remove right and top axis spines 
import numpy as np
import matplotlib.pyplot as plt
def sinplot(flip=1):
    x=np.linspace(0,14,100)
    for i in range(1,5):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)
import seaborn as sb
sb.set_style('white')
sinplot()
sb.despine()
plt.show()

# %%
#Building Color palette 
import matplotlib.pyplot as plt
import seaborn as sb;
x=sb.color_palette()
sb.palplot(x)
plt.show()

# %%
#Building Greens Color palette 
import matplotlib.pyplot as plt
import seaborn as sb
x=sb.color_palette("Greens")
sb.palplot(x)
plt.show()

# %%
#building of Diverging Color palette
import matplotlib.pyplot as plt
import seaborn as sb
x=sb.color_palette("BrBG",9)
sb.palplot(x)
plt.show()

# %%
#Setting the default Color palette
import matplotlib.pyplot as plt
import numpy as np
def lakhan(flip=1):
    x=np.linspace(0,14,100)
    for i in range(1,5):
        plt.plot(x,np.sin(x+i*5)*(7-i)*flip)
import seaborn as sb
sb.set_style("white")
sb.set_palette("husl")
lakhan()
plt.show()

# %%
#Plotting univarate Distribution--->seaborn-histogram
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
x=sb.load_dataset('iris')
sb.distplot(x['petal_length'],kde=False)
plt.show()
# Out:
# C:\Users\Saurabh\AppData\Local\Temp\ipykernel_5092\4039898806.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(x['petal_length'],kde=False)

# %%
#Seaborn-keranal Density Estimates---> seaborn-Kernal Density Estimates
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
x=sb.load_dataset('iris')
sb.distplot(x['petal_length'],hist=False)
plt.show()
# Out:
# C:\Users\Saurabh\AppData\Local\Temp\ipykernel_5092\515355289.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(x['petal_length'],hist=False)

# %%
#Fitting parametric Distributio---->bothads rbgrvfecdwwsaKUMJYHTGRFi
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
x=sb.load_dataset('iris')
sb.distplot(x['petal_length'])
plt.show()
# Out:
# C:\Users\Saurabh\AppData\Local\Temp\ipykernel_5092\552696704.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(x['petal_length'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
df=sb.load_dataset('iris')
sb.jointplot(x="petal_length" ,y="petal_width",data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
df=sb.load_dataset('iris')
sb.jointplot(x="petal_length" ,y="petal_width",data=df,kind="hex")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
x=sb.load_dataset('iris')
# sb.jointplot(x="petal_length" ,y="petal_width",data=x,kind="hex")
g=sb.PairGrid(df)
g.map(plt.scatter)
plt.show()
